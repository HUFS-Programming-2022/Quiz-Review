# %%
"""
1. text5에서 4번 출현하는 단어들을 중복되지 않게 오름차순으로 출력하시오
"""

import nltk
nltk.download('book', quiet = True)#
from nltk import book
from nltk import FreqDist

fdist5 = FreqDist(text5)

sorted(set([word for word in text5 if fdist5[word] == 4 and word.isalpha()]))
#count보다 fdist가 더 빠른 듯함.
#text = book.text 필요 없음.
# Out:
# ['Any',
#  'Dawnstar',
#  'EST',
#  'Everyone',
#  'Florida',
#  'Go',
#  'Kittie',
#  'Like',
#  'MY',
#  'Messaging',
#  'N',
#  'ONE',
#  'Ok',
#  'Private',
#  'ROOM',
#  'S',
#  'South',
#  'To',
#  'U',
#  'Visit',
#  'We',
#  'Wellbutrin',
#  'White',
#  'Wow',
#  'afternoon',
#  'ahh',
#  'alright',
#  'asses',
#  'barbie',
#  'beat',
#  'behind',
#  'between',
#  'bitch',
#  'blank',
#  'box',
#  'bring',
#  'c',
#  'calling',
#  'caught',
#  'charge',
#  'cheap',
#  'choice',
#  'claws',
#  'com',
#  'country',
#  'cup',
#  'cute',
#  'dam',
#  'dances',
#  'darlin',
#  'date',
#  'dating',
#  'daughter',
#  'depends',
#  'desert',
#  'different',
#  'dirty',
#  'dis',
#  'door',
#  'drive',
#  'each',
#  'evil',
#  'fabric',
#  'falls',
#  'fart',
#  'figure',
#  'found',
#  'giggles',
#  'glad',
#  'grrr',
#  'guitar',
#  'hahahaha',
#  'happens',
#  'hehehehe',
#  'hes',
#  'heyyy',
#  'high',
#  'himself',
#  'history',
#  'holy',
#  'hook',
#  'huge',
#  'id',
# ...

# %%
"""
2. text4에서 democracy는 몇 번 나오는지 출력하시오.
   text4에서는 한 번 출현하지만 text3에서는 여러 번 출현하는 단어는 몇 개인지 출력하시오
"""
#2-1.
text4 = book.text4
democracy_num = text4.count('democracy')

print(f'text4에서는 democracy가 총 {democracy_num}번 나옵니다.')
# Out:
# text4에서는 democracy가 총 65번 나옵니다.

# %%
#2-2.
text3 = book.text3

fdist3 = FreqDist(text3)
fdist4 = FreqDist(text4)

[word for word in text4 if fdist4[word] == 1 and fdist3[word] > 1 and word.isalpha]
# Out:
# ['thence',
#  'token',
#  'behold',
#  'fifth',
#  'perceived',
#  'pieces',
#  'mouth',
#  'handmaid',
#  'covering',
#  'fell',
#  'hunter',
#  'Israel',
#  'trespass',
#  'knife',
#  'Blessed',
#  'corrupt',
#  'graciously',
#  'fish',
#  'rose',
#  'shut',
#  'twelve',
#  'kindled',
#  'ark',
#  'confound',
#  'arose',
#  'evening',
#  'whomsoever',
#  'neck',
#  'interpreted',
#  'clothes',
#  'balm',
#  'whence',
#  'elder',
#  'Egypt',
#  'younger',
#  'abode',
#  'forbid',
#  'eighty',
#  'princes',
#  'green',
#  'bare',
#  'seventy',
#  'fifteen',
#  'dry',
#  'husband',
#  'wife',
#  'wickedness',
#  'widow',
#  'afflict',
#  'stead',
#  'fountains',
#  'sixth',
#  'stretched',
#  'eastward',
#  'dress',
#  'walked',
#  'garden',
#  'cattle',
#  'thereon',
#  'sojourn',
#  'dew',
#  'stuff',
#  'fine',
#  'whither',
#  'brother',
#  'audience',
#  'builded',
#  'fountain',
#  'continually',
#  'firmament',
#  'sore',
#  'likeness',
#  'fourth',
#  'rested',
#  'tongues',
# ...

# %%
"""
4. NLTK 임포트하고, text4에서 4자리 단어만 출력하세요.
"""
import nltk
from nltk import book

[word for word in text4 if len(word) == 4]
# Out:
# ['life',
#  'have',
#  'with',
#  'than',
#  'that',
#  'your',
#  '14th',
#  'hand',
#  'hear',
#  'with',
#  'love',
#  'from',
#  'with',
#  'with',
#  'more',
#  'well',
#  'more',
#  'dear',
#  'time',
#  'hand',
#  'most',
#  'into',
#  'with',
#  'from',
#  'this',
#  'dare',
#  'aver',
#  'that',
#  'been',
#  'duty',
#  'from',
#  'just',
#  'dare',
#  'hope',
#  'that',
#  'this',
#  'task',
#  'have',
#  'been',
#  'much',
#  'this',
#  'have',
#  'well',
#  'will',
#  'with',
#  'some',
#  'they',
#  'Such',
#  'have',
#  'omit',
#  'this',
#  'that',
#  'over',
#  'aids',
#  'that',
#  'with',
#  'this',
#  'good',
#  'that',
#  'your',
#  'less',
#  'than',
#  'less',
#  'than',
#  'Hand',
#  'more',
#  'than',
#  'step',
#  'they',
#  'have',
#  'have',
#  'been',
#  'some',
#  'just',
#  'many',
#  'from',
#  'with',
#  'most',
#  'have',
#  'been',
#  'some',
#  'with',
#  'past',
#  'seem',
#  'have',
#  'mind',
#  'will',
#  'join',
#  'with',
#  'that',
# ...
