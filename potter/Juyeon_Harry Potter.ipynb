# %% [markdown]
# ## MidTerm - 해리포터 텍스트 정제
# - 조건
#     - 문제 없이 정제될 것
# - 문제
#     - 파일 불러오기
#     - 문장 분절하기

# %%
# 1. 함수 만들기
# 텍스트를 정리_word = data.split()
def organize_sentence(data):
    data_organize = ''.join([line.strip('...,\‘’“”!?\/1234567890\n—-|();:').replace(' — ', '—').replace(' - ', '-')\
                         .replace('Mr.', 'Mr').replace('Mrs.', 'Mrs').replace('won\'t','will not')\
                         .replace('n’t', ' not').replace('Page', ' ').replace(' Page   Harry Potter and the Philosophers Stone  JK Rowling ', ' ')
                         for line in data])
    
    return data_organize

#단어를 분절하는 함수
def tokenize_word(data):
    #data_word = ''.join([line.split() for line in data])
    data_word = data.split()
    
    return data_word

# 2. 파일 불러오기
"""
<기존에 문제에서 주어진 방식>
with open('HarryPotter.txt', encoding='utf-8') as f:
    data = f.read()
data
"""
# <새로 배운 방식>
f = open('HarryPotter.txt', 'r', encoding='utf-8')

# 3. 정제하기

data = f.read()

tokenize_word(organize_sentence(data))
# Out:
# ['THE',
#  'BOY',
#  'WHO',
#  'LIVED',
#  'Mr',
#  'and',
#  'Mrs',
#  'Dursley',
#  'of',
#  'number',
#  'four',
#  'Privet',
#  'Drive',
#  'were',
#  'proud',
#  'to',
#  'say',
#  'that',
#  'they',
#  'were',
#  'perfectly',
#  'normal',
#  'thank',
#  'you',
#  'very',
#  'much',
#  'They',
#  'were',
#  'the',
#  'last',
#  'people',
#  'youd',
#  'expect',
#  'to',
#  'be',
#  'involved',
#  'in',
#  'anything',
#  'strange',
#  'or',
#  'mysterious',
#  'because',
#  'they',
#  'just',
#  'didnt',
#  'hold',
#  'with',
#  'such',
#  'nonsense',
#  'Mr',
#  'Dursley',
#  'was',
#  'the',
#  'director',
#  'of',
#  'a',
#  'firm',
#  'called',
#  'Grunnings',
#  'which',
#  'made',
#  'drills',
#  'He',
#  'was',
#  'a',
#  'big',
#  'beefy',
#  'man',
#  'with',
#  'hardly',
#  'any',
#  'neck',
#  'although',
#  'he',
#  'did',
#  'have',
#  'a',
#  'very',
#  'large',
#  'mustache',
#  'Mrs',
#  'Dursley',
#  'was',
#  'thin',
#  'and',
#  'blonde',
#  'and',
#  'had',
# ...
